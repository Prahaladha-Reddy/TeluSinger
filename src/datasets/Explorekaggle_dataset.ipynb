# %%
print("hi")
# Out:
# hi

# %%
import zipfile

zip_path = "../../rawdata/telugu-lyrics.zip"
extract_path = "../../rawdata/telugu-lyrics"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Extracted to:", extract_path)
# Out:
# Extracted to: ../../rawdata/telugu-lyrics

# %%
import pandas as pd

# %%
df=pd.read_excel("../../rawdata/telugu-lyrics/telugu_lyrics.xlsx")

# %%
df
# Out:
#               movie                                      telugu_lyrics  \
# 0       doosukeltha  2010 summerలో రేణిగుంట స్టేషన్\nplatform 2 లో ...
# 1       doosukeltha  ఉగ్గు పాల రొజుల్లోనే సిగ్గు శరం వదిలేసాడే\nనిక...
# 2       doosukeltha  \n\nModati sari\nSingers: Rahul Sipligunj, Sud...
# 3       doosukeltha  సూదిమందే గుచ్చినావే గుండెల్లో సుందరాంగి\nప్రేమ...
# 4       doosukeltha  2010 summerలో రేణిగుంట స్టేషన్\nplatform 2 లో ...
# ..              ...                                                ...
# 650            SVSC  వేకువలోన గోదారి ఏరుపెక్కింది\nఆ ఎరుపేమో గోరింట...
# 651            SVSC  మేఘాల్లో సన్నాయి రాగం మోగింది మేళాలు తాళాలు వి...
# 652            SVSC  మరీ అంతగా.. మహా చింతగా.. మొహం ముడుచుకోకలా....\...
# 653          Kadali  గుంజుకున్న నిన్ను ఎదలోకే\nగుంజుకున్న నిన్నే ఎద...
# 654  geeta govindam  తదిగిన | తకఝణు |  తదిగిన | తకఝణు\nతరికిట | తదర...
#
#                         lyricist  year
# 0             Ramajogayya Sastri  2013
# ...

# %%
sirivennala_df=df[df.lyricist=="Sirivennala Sitarama Sastry"]

# %%
sirivennala_df.movie.unique()
# Out:
# array(['mahanati', 'malliswari', 'manmadhudu', 'aditya', 'aithe',
#        'murari', 'arya', 'athadu', 'paisa', 'bommarillu', 'chakram',
#        'raja', 'chandralekha', 'criminal', 'rudraveena', 'sambaram',
#        'santosham', 'fidaa', 'gulabi', 'swayamkrushi', 'thammudu',
#        'indira', 'vaana', 'varsham', 'kanche', 'khadgam', 'yevadu',
#        'yatra', 'kshana kshanam', 'sammohanam', 'SVSC'], dtype=object)
